# %% [markdown]
# ## MatplotLib :
# Matplotlib is easy to use and an amazing visualizing library in Python. It is built on NumPy arrays and designed to work with the broader SciPy stack and consists of several plots like line, bar, scatter, histogram, etc.

# %% [markdown]
# 1. Line Plot
# 2. Bar Plot
# 3. Scatter Plot
# 4. Pie Plot
# 5. Area Plot
# 6. Histogram Plot
# 7. Box Plot

# %% [markdown]
# ### 1.Line Plot :
# Line plots are drawn by joining straight lines connecting data points where the x-axis and y-axis values intersect. Line plots are the simplest form of representing data. In Matplotlib, the plot() function represents this.

# %%
import matplotlib.pyplot as plt
x = [10,20,30,40]
y = [2,4,6,8]
plt.plot(x,y)
plt.title("simple plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
import numpy as np
x = np.array([0,30,45,60,90])
y = np.sin(x)
plt.plot(x,y)
plt.title("sin graph")
plt.xlabel("angles")
plt.ylabel("sin values")
# Out:
# Text(0, 0.5, 'sin values')

# %% [markdown]
# ## 2.Bar Plot :
# The bar plots are vertical/horizontal rectangular graphs that show data comparison where you can gauge the changes over a period represented in another axis (mostly the X-axis). Each bar can store the value of one or multiple data divided in a ratio. The longer a bar becomes, the greater the value it holds. In Matplotlib, we use the bar() or barh() function to represent it.

# %%
a = [1,2,3,4,5]
b = ['sree','ram','vishnu','prudvi','om']
plt.barh(b,a,color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
plt.bar(df['Class'],df['Sepal_Length'])
# Out:
# <BarContainer object of 150 artists>

# %% [markdown]
# ## Markers
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(df['Sepal_Length'],marker='o')

# %% [markdown]
# ## Linestyle
# You can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:

# %%
y = [1,4,3,9,5,6]
plt.plot(y,marker='o',linestyle='dotted')

# %%
plt.plot(df['Sepal_Length'].head(),marker='o',linestyle='dotted')

# %% [markdown]
# ## 3.ScatterPlot:
# With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
import numpy as np
x = np.array([0,30,45,60,90])
y = np.sin(x)
plt.scatter(x,y)
plt.title("sin graph")
plt.xlabel("angles")
plt.ylabel("sin values")
# Out:
# Text(0, 0.5, 'sin values')

# %%
plt.scatter(df['Sepal_Width'],df['Sepal_Length'])

# %% [markdown]
# ## 4.Pie Plot:

# %%
marks = [90,80,70,50]
sub = ['Telugu','Hindi','English','Social']
plt.pie(marks,labels=sub,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
Class_val_counts = []
for i in df['Class'].value_counts():
    Class_val_counts.append(i)
print(Class_val_counts)
# Out:
# [50, 50, 50]

# %%
x = Class_val_counts
y = df['Class'].unique()
plt.pie(x,labels=y,autopct='%1.0f%%')
plt.legend()
plt.show()

# %% [markdown]
# ## 5.Area Plot:
# An Area Plot is an extension of a Line Chart.
# An Area Plot is obtained by filling the region between the Line Chart and the axes with a color. When more than one Area Plot is shown in the same graph, each area plot is filled with a different color.

# %%
# Example Python program to draw an overlapped area plot
# for a pandas DataFrame
import pandas as pd
import matplotlib.pyplot as plot
# Peak Temperature data for two cities
tempData    = {"City1":[99, 106, 102, 78],
               "City2":[77, 84, 80, 85]};
# Seasons              
seasons     = ("Spring", "Summer", "Fall", "Winter");
# Create a DataFrame instance
dataFrame   = pd.DataFrame(tempData, index=seasons);
#Draw an area plot for the DataFrame data
dataFrame.plot(kind='area', stacked=False)
plot.show(block=True);

# %%
ax = df.plot.area(stacked=False)

# %%
ax = df.plot.area(x='Class')

# %% [markdown]
# ## 6.Histogram :
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
# Out:
# (array([ 3., 18., 25., 38., 50., 36., 43., 22., 11.,  4.]),
#  array([146.25394754, 151.22566874, 156.19738995, 161.16911115,
#         166.14083235, 171.11255356, 176.08427476, 181.05599597,
#         186.02771717, 190.99943838, 195.97115958]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Sepal_Length'],bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # 7.Box Plot:
# A box and whisker plot or diagram (otherwise known as a boxplot), is a graph summarising a set of data. The shape of the boxplot shows how the data is distributed and it also shows any outliers. It is a useful way to compare different sets of data as you can draw more than one boxplot per graph.

# %%
plt.figure(figsize = (10, 7)) 
df.boxplot()
# Out:
# <Axes: >
